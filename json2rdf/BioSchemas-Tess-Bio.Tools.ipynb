# %% [markdown]
# # Bioinformatics tools and training materials knowledge graph
# ### BioSchemas to bridge Bio.Tools and TeSS
#
# **Issue and objective**: TeSS training materials are not always annotated with the EDAM Bioinformatics ontology. Since Bio.Tools softwares are annotated with EDAZM in terms of topics and operations, the idea would be to navigate through training materials and their, associated softwares, to retrieve relevant EDAM annotations.
#
# **Results**: we build a knowledge graph (KG) leveraging i) the EDAM ontology, ii) BioSchemas tools and training material profiles, and iii) lifted content from Bio.Tools and TeSS. This KG can further be exploited with semantic queries (SPARQL), for instance we can search a training material based on bioinformatics definition or synonyms formalized in th EDAM ontology.
#
# Contact : alban.gaignard@univ-nantes.fr
#
# Work done during the [Elixir BioHackathon 2019](https://www.biohackathon-europe.org)

# %% [markdown]
# # 1. Transforming a TeSS entry to BioSchema

# %%
import json
import requests
import urllib3
import pandas as pd
from rdflib import ConjunctiveGraph
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

#url = 'https://tess.elixir-europe.org/materials.json_api?scientific_topics=RNA-Seq'
url = 'https://tess.elixir-europe.org/materials.json_api'
    
r = requests.get(url)
training = r.json()

#print(json.dumps(training, indent=2))

def rdfize_tess(item):
    jsonld = {}
    jsonld['@context'] = {
        "edam": "http://edamontology.org/",
        "schema": "http://schema.org/", 
        "name": "schema:name",
        "hasPart": "schema:hasPart"
    }
    jsonld['@graph'] = []

    #print(item['attributes']['title'])
    #print()
    #print(item['attributes'])
    #print()
    if item['attributes']['external-resources'] : 
        for extr in item['attributes']['external-resources']:
            #print(extr)
            if 'bio.tools' in extr['url']:
                #print('\t' + str(extr['url']))
                tess_biotools_entry = {'@id':item['attributes']['url'], 
                 '@type': 'schema:CreativeWork', 
                 'name':item['attributes']['title'], 
                 'hasPart':{'@id':extr['url']}}
                jsonld['@graph'].append(tess_biotools_entry)
                
    return json.dumps(jsonld, indent=4, sort_keys=True)

print('Sample JSON-LD data for the a TeSS training material\n')
for item in training['data']:
    print(rdfize_tess(item))
    break
# Out:
# Sample JSON-LD data for the a TeSS training material
#
# {
#     "@context": {
#         "edam": "http://edamontology.org/",
#         "hasPart": "schema:hasPart",
#         "name": "schema:name",
#         "schema": "http://schema.org/"
#     },
#     "@graph": [
#         {
#             "@id": "https://doi.org/10.5281/zenodo.3689221",
#             "@type": "schema:CreativeWork",
#             "hasPart": {
#                 "@id": "https://bio.tools/tool/Data_Stewardship_Wizard"
#             },
#             "name": "Data Stewardship Wizard Workshop (Feb 2020)"
#         }
#     ]
# }

# %% [markdown]
# # 2. Crawling the whole TeSS registry

# %%
def crawl_tess(limit=-1):
    graph = ConjunctiveGraph()
    
    """
    Go through all TeSS entries and print the tool home page if the keyword is found in the tool description.  
    :param limit: an integer value specifying the max number of entries to be crawled, -1 by default, means no limit.
    """
    
    http = urllib3.PoolManager()
    http.headers['Accept'] = 'application/json'
    http.headers['Content-type'] = 'application/json'
    
    try:
        req = http.request('GET', 'https://tess.elixir-europe.org/materials.json_api?page=1')
        count_json = json.loads(req.data.decode('utf-8'))
        #print(json.dumps(count_json, indent=2))
        count = int(count_json['meta']['results-count'])
        #print(str(count)+ " available TeSS entries")

        i = 1
        nb_tools = 1
        has_next_page = True
        while has_next_page :
            #print('Crawling page '+str(i))
            req = http.request('GET', 'https://tess.elixir-europe.org/materials.json_api?page=' + str(i))
            try:
                entry = json.loads(req.data.decode('utf-8'))
            except JSONDecodeError as e:
                print("Json decode error for " + str(req.data.decode('utf-8')))
                break
            
            #print(json.dumps(entry['links'], indent=2))
            has_next_page = ('next' in entry['links'].keys())
            

            for tool in entry['data']:
                jsonld = rdfize_tess(tool)
                graph.parse(data=jsonld, format='json-ld')
                #print(len(graph))
                
                #temp_graph = ConjunctiveGraph()
                #temp_graph.parse(data=jsonld, format='json-ld')
                #os.makedirs('./bio.tools.dataset/'+tool['biotoolsID'], exist_ok=True)
                #temp_graph.serialize(format="json-ld", 
                #                     auto_compact=True, 
                #                     destination=str('./bio.tools.dataset/'+tool['biotoolsID']+'/'+tool['biotoolsID']+'.jsonld'))
                
                nb_tools += 1
                progress = nb_tools * 100 / count
                if (nb_tools % 200 == 0) :
                    print(str(round(progress))+" % done")
                if ((limit != -1) and (nb_tools >= limit)):
                    return graph
            i += 1

    except urllib3.exceptions.HTTPError as e:
        print(e)
    
    return graph

g = crawl_tess(limit=-1)
print(len(g))
g.serialize(format='turtle', destination='tess.bioschema.ttl')
print('BioSchema output produced at tess.bioschema.ttl')
g.serialize(format='json-ld', auto_compact=True, destination='tess.bioschema.jsonld')
print('BioSchema output produced at tess.bioschema.jsonld')
# Out:
# 15 % done
# 29 % done
# 44 % done
# 59 % done
# 74 % done
# 88 % done
# 666
# BioSchema output produced at tess.bioschema.ttl
# BioSchema output produced at tess.bioschema.jsonld

# %% [markdown]
# # 3. Feeding the KG

# %%
# %%time
from rdflib import ConjunctiveGraph
kg = ConjunctiveGraph()# 2. Crawling the whole TeSS registry
kg.parse('tess.bioschema.ttl', format='turtle')
print(len(kg))
kg.parse('biotools.bioschema.ttl', format='turtle')
print(len(kg))
kg.parse('/Users/gaignard-a/Documents/Dev/fresh-toolbox/EDAM.owl')
print(len(kg))
# Out:
# 666
# 196201
# 229690
# CPU times: user 16.1 s, sys: 157 ms, total: 16.3 s
# Wall time: 16.4 s

# %% [markdown]
# # 4. Querying the KG
# This query searches for training materials having as "part-of" relation some tools. The descriptions of the tools are then navigated to retreive their names, their associated topics, and the operations they perform.

# %%
query = """
SELECT ?mat_label ?t_label ?op_label ?tool_name WHERE {
    # ?mat schema:hasPart ?tool ;
        schema:name ?mat_label .
    # ?tool schema:applicationSubCategory ?topic ;
       schema:featureList ?operation ;
       schema:name ?tool_name .
    # ?topic rdfs:label ?t_label .
    # ?operation rdfs:label ?op_label .
}
"""
res_data = []
results = kg.query(query)
for r in results:
    #print(r)
    res_data.append({'Training material':str(r['mat_label']), 'Tool':str(r['tool_name']), 'Topic':str(r['t_label']), 'Operation':str(r['op_label'])})   
        
df = pd.DataFrame(res_data)
df
# Out:
#                     Operation          Tool                       Topic  \
# 0     Statistical calculation  Bioconductor       Computational biology
# 1                    Analysis  Bioconductor       Computational biology
# 2               Data handling  Bioconductor       Computational biology
# 3     Statistical calculation  Bioconductor              Bioinformatics
# 4                    Analysis  Bioconductor              Bioinformatics
# 5               Data handling  Bioconductor              Bioinformatics
# 6     Statistical calculation  Bioconductor             Data management
# 7                    Analysis  Bioconductor             Data management
# 8               Data handling  Bioconductor             Data management
# 9     Statistical calculation  Bioconductor  Statistics and probability
# 10                   Analysis  Bioconductor  Statistics and probability
# 11              Data handling  Bioconductor  Statistics and probability
# 12    Statistical calculation  Bioconductor       Computational biology
# 13                   Analysis  Bioconductor       Computational biology
# 14              Data handling  Bioconductor       Computational biology
# 15    Statistical calculation  Bioconductor              Bioinformatics
# 16                   Analysis  Bioconductor              Bioinformatics
# 17              Data handling  Bioconductor              Bioinformatics
# 18    Statistical calculation  Bioconductor             Data management
# 19                   Analysis  Bioconductor             Data management
# 20              Data handling  Bioconductor             Data management
# 21    Statistical calculation  Bioconductor  Statistics and probability
# 22                   Analysis  Bioconductor  Statistics and probability
# 23              Data handling  Bioconductor  Statistics and probability
# 24    Statistical calculation  Bioconductor       Computational biology
# 25                   Analysis  Bioconductor       Computational biology
# 26              Data handling  Bioconductor       Computational biology
# 27    Statistical calculation  Bioconductor              Bioinformatics
# 28                   Analysis  Bioconductor              Bioinformatics
# 29              Data handling  Bioconductor              Bioinformatics
# ...                       ...           ...                         ...
# 2334  Statistical calculation  Bioconductor             Data management
# 2335                 Analysis  Bioconductor             Data management
# 2336            Data handling  Bioconductor             Data management
# 2337  Statistical calculation  Bioconductor  Statistics and probability
# 2338                 Analysis  Bioconductor  Statistics and probability
# 2339            Data handling  Bioconductor  Statistics and probability
# 2340  Statistical calculation  Bioconductor       Computational biology
# 2341                 Analysis  Bioconductor       Computational biology
# 2342            Data handling  Bioconductor       Computational biology
# 2343  Statistical calculation  Bioconductor              Bioinformatics
# 2344                 Analysis  Bioconductor              Bioinformatics
# 2345            Data handling  Bioconductor              Bioinformatics
# 2346  Statistical calculation  Bioconductor             Data management
# 2347                 Analysis  Bioconductor             Data management
# 2348            Data handling  Bioconductor             Data management
# 2349  Statistical calculation  Bioconductor  Statistics and probability
# 2350                 Analysis  Bioconductor  Statistics and probability
# 2351            Data handling  Bioconductor  Statistics and probability
# 2352  Statistical calculation  Bioconductor       Computational biology
# 2353                 Analysis  Bioconductor       Computational biology
# 2354            Data handling  Bioconductor       Computational biology
# 2355  Statistical calculation  Bioconductor              Bioinformatics
# 2356                 Analysis  Bioconductor              Bioinformatics
# 2357            Data handling  Bioconductor              Bioinformatics
# 2358  Statistical calculation  Bioconductor             Data management
# 2359                 Analysis  Bioconductor             Data management
# 2360            Data handling  Bioconductor             Data management
# 2361  Statistical calculation  Bioconductor  Statistics and probability
# 2362                 Analysis  Bioconductor  Statistics and probability
# 2363            Data handling  Bioconductor  Statistics and probability
#
#                                       Training material
# 0                         R / Bioconductor for everyone
# 1                         R / Bioconductor for everyone
# 2                         R / Bioconductor for everyone
# 3                         R / Bioconductor for everyone
# 4                         R / Bioconductor for everyone
# 5                         R / Bioconductor for everyone
# 6                         R / Bioconductor for everyone
# 7                         R / Bioconductor for everyone
# 8                         R / Bioconductor for everyone
# 9                         R / Bioconductor for everyone
# 10                        R / Bioconductor for everyone
# 11                        R / Bioconductor for everyone
# 12    Bioconductor for 'Omics Analysis (University o...
# 13    Bioconductor for 'Omics Analysis (University o...
# 14    Bioconductor for 'Omics Analysis (University o...
# 15    Bioconductor for 'Omics Analysis (University o...
# 16    Bioconductor for 'Omics Analysis (University o...
# 17    Bioconductor for 'Omics Analysis (University o...
# 18    Bioconductor for 'Omics Analysis (University o...
# 19    Bioconductor for 'Omics Analysis (University o...
# 20    Bioconductor for 'Omics Analysis (University o...
# 21    Bioconductor for 'Omics Analysis (University o...
# 22    Bioconductor for 'Omics Analysis (University o...
# 23    Bioconductor for 'Omics Analysis (University o...
# 24    Working with Ranges infrastructure: annotating...
# 25    Working with Ranges infrastructure: annotating...
# 26    Working with Ranges infrastructure: annotating...
# 27    Working with Ranges infrastructure: annotating...
# 28    Working with Ranges infrastructure: annotating...
# 29    Working with Ranges infrastructure: annotating...
# ...                                                 ...
# 2334    R / Bioconductor for 'Omics Analysis (U. Idaho)
# 2335    R / Bioconductor for 'Omics Analysis (U. Idaho)
# 2336    R / Bioconductor for 'Omics Analysis (U. Idaho)
# 2337    R / Bioconductor for 'Omics Analysis (U. Idaho)
# 2338    R / Bioconductor for 'Omics Analysis (U. Idaho)
# 2339    R / Bioconductor for 'Omics Analysis (U. Idaho)
# 2340                  Variant calling with Bioconductor
# 2341                  Variant calling with Bioconductor
# 2342                  Variant calling with Bioconductor
# 2343                  Variant calling with Bioconductor
# 2344                  Variant calling with Bioconductor
# 2345                  Variant calling with Bioconductor
# 2346                  Variant calling with Bioconductor
# 2347                  Variant calling with Bioconductor
# 2348                  Variant calling with Bioconductor
# 2349                  Variant calling with Bioconductor
# 2350                  Variant calling with Bioconductor
# 2351                  Variant calling with Bioconductor
# 2352     eQTL analysis -- an approach with Bioconductor
# 2353     eQTL analysis -- an approach with Bioconductor
# 2354     eQTL analysis -- an approach with Bioconductor
# 2355     eQTL analysis -- an approach with Bioconductor
# 2356     eQTL analysis -- an approach with Bioconductor
# 2357     eQTL analysis -- an approach with Bioconductor
# 2358     eQTL analysis -- an approach with Bioconductor
# 2359     eQTL analysis -- an approach with Bioconductor
# 2360     eQTL analysis -- an approach with Bioconductor
# 2361     eQTL analysis -- an approach with Bioconductor
# 2362     eQTL analysis -- an approach with Bioconductor
# 2363     eQTL analysis -- an approach with Bioconductor
#
# [2364 rows x 4 columns]
