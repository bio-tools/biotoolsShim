# %%
import requests
import json

#url = 'https://tess.elixir-europe.org/materials.json_api?scientific_topics=RNA-Seq'
url = 'https://tess.elixir-europe.org/materials.json_api'
    
r = requests.get(url)
training = r.json()

#print(json.dumps(training, indent=2))

def rdfize_tess(item):
    jsonld = {}
    jsonld['@context'] = {
        "edam": "http://edamontology.org/",
        "schema": "http://schema.org/", 
        "name": "schema:name",
        "hasPart": "schema:hasPart"
    }
    jsonld['@graph'] = []

    #print(item['attributes']['title'])
    #print()
    #print(item['attributes'])
    #print()
    if item['attributes']['external-resources'] : 
        for extr in item['attributes']['external-resources']:
            #print(extr)
            if 'bio.tools' in extr['url']:
                #print('\t' + str(extr['url']))
                tess_biotools_entry = {'@id':item['attributes']['url'], 
                 '@type': 'schema:CreativeWork', 
                 'name':item['attributes']['title'], 
                 'hasPart':{'@id':extr['url']}}
                jsonld['@graph'].append(tess_biotools_entry)
                
    return json.dumps(jsonld, indent=4, sort_keys=True)

for item in training['data']:
    print(rdfize_tess(item))
    break

# %%
from rdflib import ConjunctiveGraph
g = ConjunctiveGraph()

json_ld_as_string = json.dumps(jsonld, indent=4, sort_keys=True)
g.parse(data=json_ld_as_string, format='json-ld')
print(g.serialize(format='turtle').decode())

# %%
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

def crawl_tess(limit=-1):
    graph = ConjunctiveGraph()
    
    """
    Go through all TeSS entries and print the tool home page if the keyword is found in the tool description.  
    :param limit: an integer value specifying the max number of entries to be crawled, -1 by default, means no limit.
    """
    
    http = urllib3.PoolManager()
    http.headers['Accept'] = 'application/json'
    http.headers['Content-type'] = 'application/json'
    
    try:
        req = http.request('GET', 'https://tess.elixir-europe.org/materials.json_api?page=1')
        count_json = json.loads(req.data.decode('utf-8'))
        #print(json.dumps(count_json, indent=2))
        count = int(count_json['meta']['results-count'])
        #print(str(count)+ " available TeSS entries")

        i = 1
        nb_tools = 1
        has_next_page = True
        while has_next_page :
            #print('Crawling page '+str(i))
            req = http.request('GET', 'https://tess.elixir-europe.org/materials.json_api?page=' + str(i))
            try:
                entry = json.loads(req.data.decode('utf-8'))
            except JSONDecodeError as e:
                print("Json decode error for " + str(req.data.decode('utf-8')))
                break
            
            #print(json.dumps(entry['links'], indent=2))
            has_next_page = ('next' in entry['links'].keys())
            

            for tool in entry['data']:
                jsonld = rdfize_tess(tool)
                graph.parse(data=jsonld, format='json-ld')
                #print(len(graph))
                
                #temp_graph = ConjunctiveGraph()
                #temp_graph.parse(data=jsonld, format='json-ld')
                #os.makedirs('./bio.tools.dataset/'+tool['biotoolsID'], exist_ok=True)
                #temp_graph.serialize(format="json-ld", 
                #                     auto_compact=True, 
                #                     destination=str('./bio.tools.dataset/'+tool['biotoolsID']+'/'+tool['biotoolsID']+'.jsonld'))
                
                nb_tools += 1
                progress = nb_tools * 100 / count
                if (nb_tools % 200 == 0) :
                    print(str(round(progress))+" % done")
                if ((limit != -1) and (nb_tools >= limit)):
                    return graph
            i += 1

    except urllib3.exceptions.HTTPError as e:
        print(e)
    
    return graph

# %%
g = crawl_tess(limit=-1)
print(len(g))
g.serialize(format='turtle', destination='tess.bioschema.ttl')
print('BioSchema output produced at tess.bioschema.ttl')
g.serialize(format='json-ld', auto_compact=True, destination='tess.bioschema.jsonld')
print('BioSchema output produced at tess.bioschema.jsonld')

# %%
# %%time
from rdflib import ConjunctiveGraph
kg = ConjunctiveGraph()
kg.parse('tess.bioschema.ttl', format='turtle')
print(len(kg))
kg.parse('biotools.bioschema.ttl', format='turtle')
print(len(kg))
kg.parse('/Users/gaignard-a/Documents/Dev/fresh-toolbox/EDAM.owl')
print(len(kg))
# Out:
# 627
# 196162
# 229651
# CPU times: user 14.9 s, sys: 89.6 ms, total: 15 s
# Wall time: 15 s

# %%
import pandas as pd
query = """
SELECT ?mat_label ?t_label ?op_label ?tool_name WHERE {
    # ?mat schema:hasPart ?tool ;
        schema:name ?mat_label .
    # ?tool schema:applicationSubCategory ?topic ;
       schema:featureList ?operation ;
       schema:name ?tool_name .
    # ?topic rdfs:label ?t_label .
    # ?operation rdfs:label ?op_label .
}
"""
res_data = []
results = kg.query(query)
for r in results:
    #print(r)
    res_data.append({'Training material':str(r['mat_label']), 'Tool':str(r['tool_name']), 'Topic':str(r['t_label']), 'Operation':str(r['op_label'])})   
        
df = pd.DataFrame(res_data)
df
# Out:
#                     Operation          Tool                       Topic  \
# 0               Data handling  Bioconductor       Computational biology
# 1                    Analysis  Bioconductor       Computational biology
# 2     Statistical calculation  Bioconductor       Computational biology
# 3               Data handling  Bioconductor  Statistics and probability
# 4                    Analysis  Bioconductor  Statistics and probability
# 5     Statistical calculation  Bioconductor  Statistics and probability
# 6               Data handling  Bioconductor              Bioinformatics
# 7                    Analysis  Bioconductor              Bioinformatics
# 8     Statistical calculation  Bioconductor              Bioinformatics
# 9               Data handling  Bioconductor             Data management
# 10                   Analysis  Bioconductor             Data management
# 11    Statistical calculation  Bioconductor             Data management
# 12              Data handling  Bioconductor       Computational biology
# 13                   Analysis  Bioconductor       Computational biology
# 14    Statistical calculation  Bioconductor       Computational biology
# 15              Data handling  Bioconductor  Statistics and probability
# 16                   Analysis  Bioconductor  Statistics and probability
# 17    Statistical calculation  Bioconductor  Statistics and probability
# 18              Data handling  Bioconductor              Bioinformatics
# 19                   Analysis  Bioconductor              Bioinformatics
# 20    Statistical calculation  Bioconductor              Bioinformatics
# 21              Data handling  Bioconductor             Data management
# 22                   Analysis  Bioconductor             Data management
# 23    Statistical calculation  Bioconductor             Data management
# 24              Data handling  Bioconductor       Computational biology
# 25                   Analysis  Bioconductor       Computational biology
# 26    Statistical calculation  Bioconductor       Computational biology
# 27              Data handling  Bioconductor  Statistics and probability
# 28                   Analysis  Bioconductor  Statistics and probability
# 29    Statistical calculation  Bioconductor  Statistics and probability
# ...                       ...           ...                         ...
# 2190            Data handling  Bioconductor              Bioinformatics
# 2191                 Analysis  Bioconductor              Bioinformatics
# 2192  Statistical calculation  Bioconductor              Bioinformatics
# 2193            Data handling  Bioconductor             Data management
# 2194                 Analysis  Bioconductor             Data management
# 2195  Statistical calculation  Bioconductor             Data management
# 2196            Data handling  Bioconductor       Computational biology
# 2197                 Analysis  Bioconductor       Computational biology
# 2198  Statistical calculation  Bioconductor       Computational biology
# 2199            Data handling  Bioconductor  Statistics and probability
# 2200                 Analysis  Bioconductor  Statistics and probability
# 2201  Statistical calculation  Bioconductor  Statistics and probability
# 2202            Data handling  Bioconductor              Bioinformatics
# 2203                 Analysis  Bioconductor              Bioinformatics
# 2204  Statistical calculation  Bioconductor              Bioinformatics
# 2205            Data handling  Bioconductor             Data management
# 2206                 Analysis  Bioconductor             Data management
# 2207  Statistical calculation  Bioconductor             Data management
# 2208            Data handling  Bioconductor       Computational biology
# 2209                 Analysis  Bioconductor       Computational biology
# 2210  Statistical calculation  Bioconductor       Computational biology
# 2211            Data handling  Bioconductor  Statistics and probability
# 2212                 Analysis  Bioconductor  Statistics and probability
# 2213  Statistical calculation  Bioconductor  Statistics and probability
# 2214            Data handling  Bioconductor              Bioinformatics
# 2215                 Analysis  Bioconductor              Bioinformatics
# 2216  Statistical calculation  Bioconductor              Bioinformatics
# 2217            Data handling  Bioconductor             Data management
# 2218                 Analysis  Bioconductor             Data management
# 2219  Statistical calculation  Bioconductor             Data management
#
#                                Training material
# 0          05: Bioconductor Annotation Resources
# 1          05: Bioconductor Annotation Resources
# 2          05: Bioconductor Annotation Resources
# 3          05: Bioconductor Annotation Resources
# 4          05: Bioconductor Annotation Resources
# 5          05: Bioconductor Annotation Resources
# 6          05: Bioconductor Annotation Resources
# 7          05: Bioconductor Annotation Resources
# 8          05: Bioconductor Annotation Resources
# 9          05: Bioconductor Annotation Resources
# 10         05: Bioconductor Annotation Resources
# 11         05: Bioconductor Annotation Resources
# 12                           Gene set enrichment
# 13                           Gene set enrichment
# 14                           Gene set enrichment
# 15                           Gene set enrichment
# 16                           Gene set enrichment
# 17                           Gene set enrichment
# 18                           Gene set enrichment
# 19                           Gene set enrichment
# 20                           Gene set enrichment
# 21                           Gene set enrichment
# 22                           Gene set enrichment
# 23                           Gene set enrichment
# 24                                    Large Data
# 25                                    Large Data
# 26                                    Large Data
# 27                                    Large Data
# 28                                    Large Data
# 29                                    Large Data
# ...                                          ...
# 2190                             Gene Expression
# 2191                             Gene Expression
# 2192                             Gene Expression
# 2193                             Gene Expression
# 2194                             Gene Expression
# 2195                             Gene Expression
# 2196                Sequence Data Representation
# 2197                Sequence Data Representation
# 2198                Sequence Data Representation
# 2199                Sequence Data Representation
# 2200                Sequence Data Representation
# 2201                Sequence Data Representation
# 2202                Sequence Data Representation
# 2203                Sequence Data Representation
# 2204                Sequence Data Representation
# 2205                Sequence Data Representation
# 2206                Sequence Data Representation
# 2207                Sequence Data Representation
# 2208  Work in Progress: Bioconductor and the HCA
# 2209  Work in Progress: Bioconductor and the HCA
# 2210  Work in Progress: Bioconductor and the HCA
# 2211  Work in Progress: Bioconductor and the HCA
# 2212  Work in Progress: Bioconductor and the HCA
# 2213  Work in Progress: Bioconductor and the HCA
# 2214  Work in Progress: Bioconductor and the HCA
# 2215  Work in Progress: Bioconductor and the HCA
# 2216  Work in Progress: Bioconductor and the HCA
# 2217  Work in Progress: Bioconductor and the HCA
# 2218  Work in Progress: Bioconductor and the HCA
# 2219  Work in Progress: Bioconductor and the HCA
#
# [2220 rows x 4 columns]
